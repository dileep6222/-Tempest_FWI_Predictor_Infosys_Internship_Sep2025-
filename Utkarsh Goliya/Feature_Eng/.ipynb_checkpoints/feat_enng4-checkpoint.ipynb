# %%
import pandas as pd
import pickle
from sklearn.preprocessing import PowerTransformer, StandardScaler , OneHotEncoder

# %%
data = pd.read_csv(r"E:\Info_Srping\FWI_Prediction\Data\processed\train_data.csv")
data
# Out:
#                  report_date  temperature  dew_point_temperature  \
# 0        2019-08-27 12:00:00         12.0                    7.6
# 1        2018-06-06 12:00:00         11.1                    1.7
# 2        2014-10-11 12:00:00          2.9                    2.3
# 3        2015-09-11 12:00:00         22.1                   11.1
# 4        2016-06-22 12:00:00         17.0                   10.0
# ...                      ...          ...                    ...
# 1183935  2012-09-19 12:00:00         22.5                   15.4
# 1183936  2011-08-01 12:00:00         17.4                   12.1
# 1183937  2017-07-09 12:00:00         21.0                   15.0
# 1183938  2010-04-24 12:00:00         16.2                   -1.4
# 1183939  2017-10-05 12:00:00          6.8                   -4.3
#
#          relative_humidity  wind_speed  wind_direction  atmospheric_pressure  \
# 0                     74.4        12.0               0               1015.13
# 1                     52.0        22.1             200               1010.80
# 2                     95.0         1.9             250               1018.19
# 3                     49.8         9.5             267               1015.79
# 4                     63.6        35.2             260               1016.70
# ...                    ...         ...             ...                   ...
# 1183935               63.0        35.2             180               1016.90
# 1183936               70.0        22.2             300               1018.30
# 1183937               68.7        13.0             200               1014.50
# 1183938               31.0        25.9             220               1016.50
# 1183939               45.4        24.1             270               1014.60
#
#          visibility  precipitation  rain_days  ...  duff_moisture_code  \
# 0              30.0            2.6          0  ...                 6.9
# 1              38.6            1.5          0  ...                14.8
# 2              27.7            0.0          2  ...                 3.1
# 3              23.9            0.0          4  ...                11.4
# 4              16.1            0.0          1  ...               107.4
# ...             ...            ...        ...  ...                 ...
# 1183935        10.1            0.0          2  ...                11.5
# 1183936        49.7            0.0         10  ...                20.6
# 1183937        14.5            0.0          1  ...                 5.2
# 1183938        48.3            0.0          3  ...                12.1
# 1183939        24.0            0.0          1  ...                 4.8
#
#          drought_code  build_up_index  initial_spread_index  \
# 0                51.1            10.3                   0.9
# 1               104.2            21.9                   1.7
# 2               330.1             6.1                   0.1
# 3               282.9            20.7                   3.8
# 4               482.9           138.1                  15.6
# ...               ...             ...                   ...
# 1183935          27.6            11.5                  16.9
# 1183936         334.2            35.6                   6.1
# 1183937         107.5             9.3                   2.1
# 1183938          21.5            12.0                  15.3
# 1183939         372.8             9.2                   2.2
#
#          fire_weather_index  daily_severity_rating         country   latitude  \
# 0                       0.6                    0.0  United Kingdom  54.502224
# 1                       2.7                    0.2          Canada  55.200000
# 2                       0.0                    0.0          Canada  49.820000
# 3                       6.3                    0.7          Canada  54.280000
# 4                      47.7                   25.4   United States  37.618805
# ...                     ...                    ...             ...        ...
# 1183935                16.3                    3.8          Canada  45.230000
# 1183936                12.8                    2.5          Canada  49.350000
# 1183937                 1.8                    0.1          Canada  43.628613
# 1183938                15.4                    3.4          Canada  45.466667
# 1183939                 1.9                    0.1          Canada  55.800000
#
#          longitude  elevation
# 0         -2.68500      252.0
# 1       -119.40000      745.0
# 2        -74.98000      381.1
# 3       -111.45000      619.0
# 4       -122.37542        4.0
# ...            ...        ...
# 1183935  -63.06000       23.5
# 1183936 -124.16000       14.5
# 1183937  -79.39500       76.8
# 1183938  -73.75000       36.0
# 1183939  -97.86000      224.0
#
# [1183940 rows x 22 columns]

# %%
data = data.drop(['wind_direction','snow_on_ground','daily_severity_rating','latitude','longitude', 'elevation','visibility'], axis = 1)
data
# Out:
#                  report_date  temperature  dew_point_temperature  \
# 0        2019-08-27 12:00:00         12.0                    7.6
# 1        2018-06-06 12:00:00         11.1                    1.7
# 2        2014-10-11 12:00:00          2.9                    2.3
# 3        2015-09-11 12:00:00         22.1                   11.1
# 4        2016-06-22 12:00:00         17.0                   10.0
# ...                      ...          ...                    ...
# 1183935  2012-09-19 12:00:00         22.5                   15.4
# 1183936  2011-08-01 12:00:00         17.4                   12.1
# 1183937  2017-07-09 12:00:00         21.0                   15.0
# 1183938  2010-04-24 12:00:00         16.2                   -1.4
# 1183939  2017-10-05 12:00:00          6.8                   -4.3
#
#          relative_humidity  wind_speed  atmospheric_pressure  precipitation  \
# 0                     74.4        12.0               1015.13            2.6
# 1                     52.0        22.1               1010.80            1.5
# 2                     95.0         1.9               1018.19            0.0
# 3                     49.8         9.5               1015.79            0.0
# 4                     63.6        35.2               1016.70            0.0
# ...                    ...         ...                   ...            ...
# 1183935               63.0        35.2               1016.90            0.0
# 1183936               70.0        22.2               1018.30            0.0
# 1183937               68.7        13.0               1014.50            0.0
# 1183938               31.0        25.9               1016.50            0.0
# 1183939               45.4        24.1               1014.60            0.0
#
#          rain_days  fine_fuel_moisture_code  duff_moisture_code  drought_code  \
# 0                0                     64.1                 6.9          51.1
# 1                0                     66.2                14.8         104.2
# 2                2                     44.3                 3.1         330.1
# 3                4                     85.8                11.4         282.9
# 4                1                     86.6               107.4         482.9
# ...            ...                      ...                 ...           ...
# 1183935          2                     87.2                11.5          27.6
# 1183936         10                     84.5                20.6         334.2
# 1183937          1                     79.8                 5.2         107.5
# 1183938          3                     89.8                12.1          21.5
# 1183939          1                     71.2                 4.8         372.8
#
#          build_up_index  initial_spread_index  fire_weather_index  \
# 0                  10.3                   0.9                 0.6
# 1                  21.9                   1.7                 2.7
# 2                   6.1                   0.1                 0.0
# 3                  20.7                   3.8                 6.3
# 4                 138.1                  15.6                47.7
# ...                 ...                   ...                 ...
# 1183935            11.5                  16.9                16.3
# 1183936            35.6                   6.1                12.8
# 1183937             9.3                   2.1                 1.8
# 1183938            12.0                  15.3                15.4
# 1183939             9.2                   2.2                 1.9
#
#                 country
# 0        United Kingdom
# 1                Canada
# 2                Canada
# 3                Canada
# 4         United States
# ...                 ...
# 1183935          Canada
# 1183936          Canada
# 1183937          Canada
# 1183938          Canada
# 1183939          Canada
#
# [1183940 rows x 15 columns]

# %%
non_nd_col = ['fine_fuel_moisture_code','duff_moisture_code', 'drought_code','build_up_index', 'initial_spread_index','fire_weather_index','wind_speed']

# %%
# Dictionary to hold fitted power transformers per column
power_transformers = {}

# Fit power transformer per specified column and save each transformer object
for col in non_nd_col:
    pt = PowerTransformer(method='yeo-johnson', standardize=False)
    transformed = pt.fit_transform(data[col].values.reshape(-1, 1))
    data[col + '_transformed'] = transformed.flatten()
    power_transformers[col] = pt  # Save fitted transformer

# Save the power transformers dictionary as a pkl
with open(r'E:\Info_Srping\FWI_Prediction\models\Final_pkl_files\power_transformers.pkl', 'wb') as f:
    pickle.dump(power_transformers, f)

# %%
# Fit StandardScaler on all numerical columns (including newly added transformed columns)
scaler = StandardScaler()

# Select numeric columns from data
numeric_cols = data.select_dtypes(include=['float64', 'int']).columns

# Fit and transform scaler on all numeric features together
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])

# Save the fitted scaler as a pkl
with open(r'E:\Info_Srping\FWI_Prediction\models\Final_pkl_files\standard_scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore', dtype=int)
ohe.fit(data[['country']])

# Save the fitted encoder to a pickle file
with open(r'E:\Info_Srping\FWI_Prediction\models\Final_pkl_files\one_hot_encoder.pkl', 'wb') as f:
    pickle.dump(ohe, f)
