# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
test_data = pd.read_csv(r'E:\Info_Srping\FWI_Prediction\Data\processed\test_data.csv')
test_data
# Out:
#                 report_date  temperature  dew_point_temperature  \
# 0       2015-06-26 12:00:00         20.6                    6.4
# 1       2011-08-24 12:00:00         19.0                    6.0
# 2       2010-08-13 12:00:00         15.2                    8.0
# 3       2015-12-13 12:00:00          3.6                   -1.4
# 4       2014-11-08 12:00:00          0.5                   -4.1
# ...                     ...          ...                    ...
# 315713  2014-07-19 12:00:00         24.0                   13.0
# 315714  2011-09-28 12:00:00         14.8                    4.5
# 315715  2010-08-15 12:00:00         21.0                   20.0
# 315716  2019-06-30 12:00:00         26.9                   16.3
# 315717  2015-05-31 12:00:00         16.4                    8.5
#
#         relative_humidity  wind_speed  wind_direction  atmospheric_pressure  \
# 0                    39.8         7.4             230               1016.53
# 1                    42.0         3.7             280               1015.60
# 2                    62.0        11.0             350               1021.90
# 3                    70.1        33.3             300               1004.80
# 4                    71.0        27.7             267               1001.24
# ...                   ...         ...             ...                   ...
# 315713               50.0        13.0             130               1025.20
# 315714               51.0        14.0             240               1015.74
# 315715               94.0        13.0             140               1010.00
# 315716               52.0         9.9              32               1016.20
# 315717               59.8         4.7             289               1008.21
#
#         visibility  precipitation  rain_days  ...  duff_moisture_code  \
# 0             24.0            0.0          1  ...                 9.6
# 1             24.1            0.0          1  ...                39.0
# 2             24.1            4.3          0  ...                14.3
# 3             19.9            7.2          0  ...                 0.1
# 4             22.9           23.3          0  ...                 0.1
# ...            ...            ...        ...  ...                 ...
# 315713        16.1            0.0          2  ...                14.0
# 315714        36.2            0.0          4  ...                 5.0
# 315715        14.5            6.0          0  ...                19.6
# 315716        17.7            0.0          1  ...                17.7
# 315717        18.6            3.9          0  ...                57.6
#
#         drought_code  build_up_index  initial_spread_index  \
# 0               20.8             9.5                   4.6
# 1              310.7            59.4                   3.0
# 2              481.2            26.6                   0.4
# 3                0.4             0.1                   0.0
# 4                0.0             0.0                   0.0
# ...              ...             ...                   ...
# 315713          79.4            19.5                   5.7
# 315714         177.0            10.0                   5.1
# 315715         296.5            33.7                   0.1
# 315716          99.3            24.5                   4.9
# 315717         308.0            78.5                   0.6
#
#         fire_weather_index  daily_severity_rating        country   latitude  \
# 0                      4.8                    0.4         Canada  44.710000
# 1                      9.6                    1.5         Canada  52.183056
# 2                      0.5                    0.0         Canada  64.110000
# 3                      0.0                    0.0         Canada  47.613056
# 4                      0.0                    0.0         Canada  46.780000
# ...                    ...                    ...            ...        ...
# 315713                 8.7                    1.3  United States  43.645645
# 315714                 5.0                    0.5         France  43.914722
# 315715                 0.1                    0.0         Canada  45.950000
# 315716                 8.7                    1.2         Canada  41.948612
# 315717                 2.2                    0.1         Canada  54.000000
#
#          longitude  elevation
# 0       -63.630000        3.5
# 1      -122.054170      939.7
# 2      -117.330000      221.0
# 3       -57.610280        6.7
# 4       -65.020000       21.0
# ...            ...        ...
# 315713  -70.308620       23.1
# 315714    2.116389      172.0
# 315715  -77.316666      130.1
# 315716  -82.518890      176.8
# 315717 -113.470000      680.0
#
# [315718 rows x 22 columns]

# %%
test_data = test_data.iloc[:20000]       
test_data
# Out:
#                report_date  temperature  dew_point_temperature  \
# 0      2015-06-26 12:00:00         20.6                    6.4
# 1      2011-08-24 12:00:00         19.0                    6.0
# 2      2010-08-13 12:00:00         15.2                    8.0
# 3      2015-12-13 12:00:00          3.6                   -1.4
# 4      2014-11-08 12:00:00          0.5                   -4.1
# ...                    ...          ...                    ...
# 19995  2011-10-27 12:00:00          8.3                   -9.4
# 19996  2016-10-03 12:00:00         29.4                   16.1
# 19997  2014-07-25 12:00:00         21.8                    6.5
# 19998  2018-09-22 12:00:00         11.0                    2.1
# 19999  2014-05-29 12:00:00         10.9                    4.9
#
#        relative_humidity  wind_speed  wind_direction  atmospheric_pressure  \
# 0                   39.8         7.4             230               1016.53
# 1                   42.0         3.7             280               1015.60
# 2                   62.0        11.0             350               1021.90
# 3                   70.1        33.3             300               1004.80
# 4                   71.0        27.7             267               1001.24
# ...                  ...         ...             ...                   ...
# 19995               29.0        33.3             270               1019.80
# 19996               44.6        16.7              70               1013.60
# 19997               38.4         5.5             190               1018.30
# 19998               54.0         9.5             300               1024.80
# 19999               66.8        15.5             304               1012.38
#
#        visibility  precipitation  rain_days  ...  duff_moisture_code  \
# 0            24.0            0.0          1  ...                 9.6
# 1            24.1            0.0          1  ...                39.0
# 2            24.1            4.3          0  ...                14.3
# 3            19.9            7.2          0  ...                 0.1
# 4            22.9           23.3          0  ...                 0.1
# ...           ...            ...        ...  ...                 ...
# 19995        16.1            0.0          2  ...                18.2
# 19996        16.1            0.0          6  ...                32.7
# 19997        14.6            0.1          0  ...                61.1
# 19998        29.0           15.0          0  ...                 5.6
# 19999        27.7           20.9          0  ...                 6.3
#
#        drought_code  build_up_index  initial_spread_index  fire_weather_index  \
# 0              20.8             9.5                   4.6                 4.8
# 1             310.7            59.4                   3.0                 9.6
# 2             481.2            26.6                   0.4                 0.5
# 3               0.4             0.1                   0.0                 0.0
# 4               0.0             0.0                   0.0                 0.0
# ...             ...             ...                   ...                 ...
# 19995         497.8            33.4                  17.8                27.3
# 19996         113.3            38.0                  10.5                20.0
# 19997         460.4            91.8                   1.0                 4.9
# 19998         236.0            10.6                   0.1                 0.0
# 19999          18.5             6.8                   0.0                 0.0
#
#        daily_severity_rating        country   latitude  longitude  elevation
# 0                        0.4         Canada  44.710000  -63.63000        3.5
# 1                        1.5         Canada  52.183056 -122.05417      939.7
# 2                        0.0         Canada  64.110000 -117.33000      221.0
# 3                        0.0         Canada  47.613056  -57.61028        6.7
# 4                        0.0         Canada  46.780000  -65.02000       21.0
# ...                      ...            ...        ...        ...        ...
# 19995                    9.5  United States  47.482300 -111.37028     1121.7
# 19996                    5.5  United States  29.950832  -94.02069        4.5
# 19997                    0.5         Canada  49.940000 -119.40000      456.0
# 19998                    0.0         Canada  46.274700  -75.99190      200.0
# 19999                    0.0         Canada  51.760000 -114.08000     1046.0
#
# [20000 rows x 22 columns]

# %%
test_data.columns
# Out:
# Index(['report_date', 'temperature', 'dew_point_temperature',
#        'relative_humidity', 'wind_speed', 'wind_direction',
#        'atmospheric_pressure', 'visibility', 'precipitation', 'rain_days',
#        'snow_on_ground', 'fine_fuel_moisture_code', 'duff_moisture_code',
#        'drought_code', 'build_up_index', 'initial_spread_index',
#        'fire_weather_index', 'daily_severity_rating', 'country', 'latitude',
#        'longitude', 'elevation'],
#       dtype='object')

# %%
test_data = test_data.drop(['report_date','wind_direction','snow_on_ground','daily_severity_rating','latitude','longitude', 'elevation','visibility'], axis = 1)
test_data
# Out:
#        temperature  dew_point_temperature  relative_humidity  wind_speed  \
# 0             20.6                    6.4               39.8         7.4
# 1             19.0                    6.0               42.0         3.7
# 2             15.2                    8.0               62.0        11.0
# 3              3.6                   -1.4               70.1        33.3
# 4              0.5                   -4.1               71.0        27.7
# ...            ...                    ...                ...         ...
# 19995          8.3                   -9.4               29.0        33.3
# 19996         29.4                   16.1               44.6        16.7
# 19997         21.8                    6.5               38.4         5.5
# 19998         11.0                    2.1               54.0         9.5
# 19999         10.9                    4.9               66.8        15.5
#
#        atmospheric_pressure  precipitation  rain_days  \
# 0                   1016.53            0.0          1
# 1                   1015.60            0.0          1
# 2                   1021.90            4.3          0
# 3                   1004.80            7.2          0
# 4                   1001.24           23.3          0
# ...                     ...            ...        ...
# 19995               1019.80            0.0          2
# 19996               1013.60            0.0          6
# 19997               1018.30            0.1          0
# 19998               1024.80           15.0          0
# 19999               1012.38           20.9          0
#
#        fine_fuel_moisture_code  duff_moisture_code  drought_code  \
# 0                         87.9                 9.6          20.8
# 1                         86.1                39.0         310.7
# 2                         53.6                14.3         481.2
# 3                         33.2                 0.1           0.4
# 4                         25.4                 0.1           0.0
# ...                        ...                 ...           ...
# 19995                     88.2                18.2         497.8
# 19996                     90.3                32.7         113.3
# 19997                     75.5                61.1         460.4
# 19998                     41.8                 5.6         236.0
# 19999                     36.1                 6.3          18.5
#
#        build_up_index  initial_spread_index  fire_weather_index        country
# 0                 9.5                   4.6                 4.8         Canada
# 1                59.4                   3.0                 9.6         Canada
# 2                26.6                   0.4                 0.5         Canada
# 3                 0.1                   0.0                 0.0         Canada
# 4                 0.0                   0.0                 0.0         Canada
# ...               ...                   ...                 ...            ...
# 19995            33.4                  17.8                27.3  United States
# 19996            38.0                  10.5                20.0  United States
# 19997            91.8                   1.0                 4.9         Canada
# 19998            10.6                   0.1                 0.0         Canada
# 19999             6.8                   0.0                 0.0         Canada
#
# [20000 rows x 14 columns]

# %%
# Load saved PowerTransformer dictionary
with open(r'E:\Info_Srping\FWI_Prediction\models\Pkl_files\power_transformers.pkl', 'rb') as f:
    power_transformers = pickle.load(f)

# Load saved StandardScaler
with open(r'E:\Info_Srping\FWI_Prediction\models\Pkl_files\standard_scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)

# Load saved OneHotEncoding
with open(r'E:\Info_Srping\FWI_Prediction\models\Pkl_files\one_hot_encoder.pkl', 'rb') as f:
    ohe = pickle.load(f)
    
# Load saved LR_Model
with open(r'E:\Info_Srping\FWI_Prediction\models\Pkl_files\linear_regression_model.pkl', 'rb') as f:
    LR_model = pickle.load(f)

# %%
col = ['fine_fuel_moisture_code','duff_moisture_code', 'drought_code','build_up_index', 'initial_spread_index','fire_weather_index','wind_speed']
for col, pt in power_transformers.items():
    # Transform test column using fitted transformer
    transformed = pt.transform(test_data[col].values.reshape(-1, 1))
    test_data[col + '_transformed'] = transformed.flatten()

# %%
test_data
# Out:
#        temperature  dew_point_temperature  relative_humidity  wind_speed  \
# 0             20.6                    6.4               39.8         7.4
# 1             19.0                    6.0               42.0         3.7
# 2             15.2                    8.0               62.0        11.0
# 3              3.6                   -1.4               70.1        33.3
# 4              0.5                   -4.1               71.0        27.7
# ...            ...                    ...                ...         ...
# 19995          8.3                   -9.4               29.0        33.3
# 19996         29.4                   16.1               44.6        16.7
# 19997         21.8                    6.5               38.4         5.5
# 19998         11.0                    2.1               54.0         9.5
# 19999         10.9                    4.9               66.8        15.5
#
#        atmospheric_pressure  precipitation  rain_days  \
# 0                   1016.53            0.0          1
# 1                   1015.60            0.0          1
# 2                   1021.90            4.3          0
# 3                   1004.80            7.2          0
# 4                   1001.24           23.3          0
# ...                     ...            ...        ...
# 19995               1019.80            0.0          2
# 19996               1013.60            0.0          6
# 19997               1018.30            0.1          0
# 19998               1024.80           15.0          0
# 19999               1012.38           20.9          0
#
#        fine_fuel_moisture_code  duff_moisture_code  drought_code  ...  \
# 0                         87.9                 9.6          20.8  ...
# 1                         86.1                39.0         310.7  ...
# 2                         53.6                14.3         481.2  ...
# 3                         33.2                 0.1           0.4  ...
# 4                         25.4                 0.1           0.0  ...
# ...                        ...                 ...           ...  ...
# 19995                     88.2                18.2         497.8  ...
# 19996                     90.3                32.7         113.3  ...
# 19997                     75.5                61.1         460.4  ...
# 19998                     41.8                 5.6         236.0  ...
# 19999                     36.1                 6.3          18.5  ...
#
#        initial_spread_index  fire_weather_index        country  \
# 0                       4.6                 4.8         Canada
# 1                       3.0                 9.6         Canada
# 2                       0.4                 0.5         Canada
# 3                       0.0                 0.0         Canada
# 4                       0.0                 0.0         Canada
# ...                     ...                 ...            ...
# 19995                  17.8                27.3  United States
# 19996                  10.5                20.0  United States
# 19997                   1.0                 4.9         Canada
# 19998                   0.1                 0.0         Canada
# 19999                   0.0                 0.0         Canada
#
#       fine_fuel_moisture_code_transformed  duff_moisture_code_transformed  \
# 0                           181663.314979                        2.750298
# 1                           171064.548612                        4.698002
# 2                            43360.394722                        3.256324
# 3                            10965.203865                        0.095886
# 4                             5124.065815                        0.095886
# ...                                   ...                             ...
# 19995                       183470.813392                        3.581337
# 19996                       196456.479806                        4.427928
# 19997                       116825.678402                        5.418509
# 19998                        21198.959557                        2.130757
# 19999                        13928.354515                        2.259489
#
#        drought_code_transformed  build_up_index_transformed  \
# 0                      6.014914                    2.960614
# 1                     21.881419                    6.194333
# 2                     26.467105                    4.614187
# 3                      0.359823                    0.096174
# 4                      0.000000                    0.000000
# ...                         ...                         ...
# 19995                 26.856914                    5.035176
# 19996                 13.901775                    5.283034
# 19997                 25.967020                    7.165390
# 19998                 19.380179                    3.117459
# 19999                  5.647025                    2.509831
#
#        initial_spread_index_transformed  fire_weather_index_transformed  \
# 0                              1.609008                        1.757849
# 1                              1.311980                        2.360838
# 2                              0.331971                        0.405465
# 3                             -0.000000                       -0.000000
# 4                             -0.000000                       -0.000000
# ...                                 ...                             ...
# 19995                          2.614132                        3.342830
# 19996                          2.217948                        3.044496
# 19997                          0.674226                        1.774943
# 19998                          0.094947                       -0.000000
# 19999                         -0.000000                       -0.000000
#
#        wind_speed_transformed
# 0                    2.884645
# 1                    1.925242
# 2                    3.553845
# 3                    5.948134
# 4                    5.491993
# ...                       ...
# 19995                5.948134
# 19996                4.361096
# 19997                2.442188
# 19998                3.295660
# 19999                4.208880
#
# [20000 rows x 21 columns]

# %%
numeric_cols = test_data.select_dtypes(include=['float64', 'int']).columns
test_data[numeric_cols] = scaler.transform(test_data[numeric_cols])

# %%
test_data
# Out:
#        temperature  dew_point_temperature  relative_humidity  wind_speed  \
# 0         0.491152              -0.189652          -0.904141   -0.891085
# 1         0.272750              -0.247354          -0.796324   -1.323042
# 2        -0.245955               0.041156           0.183836   -0.470803
# 3        -1.829370              -1.314841           0.580800    2.132612
# 4        -2.252524              -1.704330           0.624907    1.478839
# ...            ...                    ...                ...         ...
# 19995    -1.187814              -2.468882          -1.433427    2.132612
# 19996     1.692363               1.209623          -0.668903    0.194644
# 19997     0.654953              -0.175226          -0.972752   -1.112901
# 19998    -0.819261              -0.809948          -0.208228   -0.645921
# 19999    -0.832911              -0.406034           0.419074    0.054550
#
#        atmospheric_pressure  precipitation  rain_days  \
# 0                  0.267098      -0.369007  -0.342258
# 1                  0.127932      -0.369007  -0.342258
# 2                  1.070668       0.297989  -0.597253
# 3                 -1.488187       0.747824  -0.597253
# 4                 -2.020907       3.245184  -0.597253
# ...                     ...            ...        ...
# 19995              0.756423      -0.369007  -0.087263
# 19996             -0.171349      -0.369007   0.932717
# 19997              0.531962      -0.353496  -0.597253
# 19998              1.504626       1.957725  -0.597253
# 19999             -0.353911       2.872907  -0.597253
#
#        fine_fuel_moisture_code  duff_moisture_code  drought_code  ...  \
# 0                     0.694846           -0.561405     -1.102511  ...
# 1                     0.602768            0.530596      0.372922  ...
# 2                    -1.059746           -0.386834      1.240675  ...
# 3                    -2.103293           -0.914263     -1.206336  ...
# 4                    -2.502296           -0.914263     -1.208372  ...
# ...                        ...                 ...           ...  ...
# 19995                 0.710192           -0.241976      1.325160  ...
# 19996                 0.817616            0.296596     -0.631736  ...
# 19997                 0.060533            1.351454      1.134814  ...
# 19998                -1.663366           -0.709977     -0.007260  ...
# 19999                -1.954946           -0.683977     -1.114217  ...
#
#        initial_spread_index  fire_weather_index        country  \
# 0                 -0.065365           -0.425020         Canada
# 1                 -0.333021           -0.059559         Canada
# 2                 -0.767962           -0.752412         Canada
# 3                 -0.834876           -0.790481         Canada
# 4                 -0.834876           -0.790481         Canada
# ...                     ...                 ...            ...
# 19995              2.142799            1.288078  United States
# 19996              0.921618            0.732273  United States
# 19997             -0.667591           -0.417406         Canada
# 19998             -0.818148           -0.790481         Canada
# 19999             -0.834876           -0.790481         Canada
#
#       fine_fuel_moisture_code_transformed  duff_moisture_code_transformed  \
# 0                                0.788009                       -0.406332
# 1                                0.624721                        0.874054
# 2                               -1.342731                       -0.073680
# 3                               -1.841822                       -2.151297
# 4                               -1.931812                       -2.151297
# ...                                   ...                             ...
# 19995                            0.815856                        0.139978
# 19996                            1.015918                        0.696512
# 19997                           -0.210901                        1.347702
# 19998                           -1.684157                       -0.813608
# 19999                           -1.796170                       -0.728982
#
#        drought_code_transformed  build_up_index_transformed  \
# 0                     -1.485611                   -0.752136
# 1                      0.588680                    0.900611
# 2                      1.188186                    0.093002
# 3                     -2.224924                   -2.216145
# 4                     -2.271965                   -2.265299
# ...                         ...                         ...
# 19995                  1.239147                    0.308168
# 19996                 -0.454530                    0.434848
# 19997                  1.122808                    1.396916
# 19998                  0.261683                   -0.671973
# 19999                 -1.533707                   -0.982530
#
#        initial_spread_index_transformed  fire_weather_index_transformed  \
# 0                              0.394799                       -0.010776
# 1                              0.015357                        0.483718
# 2                             -1.236570                       -1.119826
# 3                             -1.660652                       -1.452336
# 4                             -1.660652                       -1.452336
# ...                                 ...                             ...
# 19995                          1.678810                        1.289020
# 19996                          1.172700                        1.044365
# 19997                         -0.799352                        0.003243
# 19998                         -1.539361                       -1.452336
# 19999                         -1.660652                       -1.452336
#
#        wind_speed_transformed
# 0                   -0.909447
# 1                   -1.747926
# 2                   -0.324594
# 3                    1.767918
# 4                    1.369270
# ...                       ...
# 19995                1.767918
# 19996                0.380912
# 19997               -1.296137
# 19998               -0.550236
# 19999                0.247881
#
# [20000 rows x 21 columns]

# %%
test_data = test_data[['temperature', 'dew_point_temperature', 'relative_humidity',
        'atmospheric_pressure', 'precipitation', 'rain_days',
       'country', 'fine_fuel_moisture_code_transformed',
       'duff_moisture_code_transformed', 'drought_code_transformed',
       'build_up_index_transformed', 'initial_spread_index_transformed',
       'fire_weather_index_transformed', 'wind_speed_transformed']]

# %%
test_data['FFMC__TEMP'] = test_data['temperature'] * test_data['fine_fuel_moisture_code_transformed']
test_data['FFMC_RH'] = test_data['relative_humidity'] * test_data['fine_fuel_moisture_code_transformed']
test_data['RH_TEMP'] = test_data['temperature'] * test_data['relative_humidity']
test_data['RD_FFMC'] =  test_data['fine_fuel_moisture_code_transformed'] * test_data['rain_days']
test_data['DC_RD'] =  test_data['drought_code_transformed'] * test_data['rain_days']
test_data['WS_TENP'] =  test_data['wind_speed_transformed'] * test_data['fine_fuel_moisture_code_transformed']
test_data['IST_WS'] =  test_data['wind_speed_transformed'] * test_data['initial_spread_index_transformed']
test_data['ISI_FFMC'] =  test_data['initial_spread_index_transformed'] * test_data['fine_fuel_moisture_code_transformed']
test_data['ISI_RH'] =  test_data['initial_spread_index_transformed'] * test_data['relative_humidity']
test_data['DMC_TEMP'] =  test_data['duff_moisture_code_transformed'] * test_data['temperature']
test_data['DMC_RD'] =  test_data['duff_moisture_code_transformed'] * test_data['rain_days']
test_data['RD_TEMP'] =  test_data['rain_days'] * test_data['temperature']
test_data['DMC_DC'] =  test_data['drought_code_transformed'] * test_data['duff_moisture_code_transformed']
test_data['BUI_DC'] =  test_data['drought_code_transformed'] * test_data['build_up_index_transformed']
test_data['BUI_DMC'] =  test_data['duff_moisture_code_transformed'] * test_data['build_up_index_transformed']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17032\3843077778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['FFMC__TEMP'] = test_data['temperature'] * test_data['fine_fuel_moisture_code_transformed']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17032\3843077778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['FFMC_RH'] = test_data['relative_humidity'] * test_data['fine_fuel_moisture_code_transformed']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17032\3843077778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['RH_TEMP'] = test_data['temperature'] * test_data['relative_humidity']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17032\3843077778.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['RD_FFMC'] =  test_data['fine_fuel_moisture_code_transformed'] * test_data['rain_days']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17032\3843077778.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['DC_RD'] =  test_data['drought_code_transformed'] * test_data['rain_days']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17032\3843077778.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['WS_TENP'] =  test_data['wind_speed_transformed'] * test_data['fine_fuel_moisture_code_transformed']

# %%
test_data
# Out:
#        temperature  dew_point_temperature  relative_humidity  \
# 0         0.491152              -0.189652          -0.904141
# 1         0.272750              -0.247354          -0.796324
# 2        -0.245955               0.041156           0.183836
# 3        -1.829370              -1.314841           0.580800
# 4        -2.252524              -1.704330           0.624907
# ...            ...                    ...                ...
# 19995    -1.187814              -2.468882          -1.433427
# 19996     1.692363               1.209623          -0.668903
# 19997     0.654953              -0.175226          -0.972752
# 19998    -0.819261              -0.809948          -0.208228
# 19999    -0.832911              -0.406034           0.419074
#
#        atmospheric_pressure  precipitation  rain_days        country  \
# 0                  0.267098      -0.369007  -0.342258         Canada
# 1                  0.127932      -0.369007  -0.342258         Canada
# 2                  1.070668       0.297989  -0.597253         Canada
# 3                 -1.488187       0.747824  -0.597253         Canada
# 4                 -2.020907       3.245184  -0.597253         Canada
# ...                     ...            ...        ...            ...
# 19995              0.756423      -0.369007  -0.087263  United States
# 19996             -0.171349      -0.369007   0.932717  United States
# 19997              0.531962      -0.353496  -0.597253         Canada
# 19998              1.504626       1.957725  -0.597253         Canada
# 19999             -0.353911       2.872907  -0.597253         Canada
#
#        fine_fuel_moisture_code_transformed  duff_moisture_code_transformed  \
# 0                                 0.788009                       -0.406332
# 1                                 0.624721                        0.874054
# 2                                -1.342731                       -0.073680
# 3                                -1.841822                       -2.151297
# 4                                -1.931812                       -2.151297
# ...                                    ...                             ...
# 19995                             0.815856                        0.139978
# 19996                             1.015918                        0.696512
# 19997                            -0.210901                        1.347702
# 19998                            -1.684157                       -0.813608
# 19999                            -1.796170                       -0.728982
#
#        drought_code_transformed  ...   WS_TENP    IST_WS  ISI_FFMC    ISI_RH  \
# 0                     -1.485611  ... -0.716653 -0.359049  0.311105 -0.356954
# 1                      0.588680  ... -1.091966 -0.026843  0.009594 -0.012229
# 2                      1.188186  ...  0.435842  0.401383  1.660381 -0.227326
# 3                     -2.224924  ... -3.256189 -2.935896  3.058625 -0.964507
# 4                     -2.271965  ... -2.645172 -2.273880  3.208068 -1.037754
# ...                         ...  ...       ...       ...       ...       ...
# 19995                  1.239147  ...  1.442367  2.967998  1.369668 -2.406452
# 19996                 -0.454530  ...  0.386975  0.446695  1.191366 -0.784422
# 19997                  1.122808  ...  0.273356  1.036069  0.168584  0.777571
# 19998                  0.261683  ...  0.926685  0.847012  2.592526  0.320538
# 19999                 -1.533707  ... -0.445236 -0.411644  2.982814 -0.695936
#
#        DMC_TEMP    DMC_RD   RD_TEMP    DMC_DC    BUI_DC   BUI_DMC
# 0     -0.199571  0.139071 -0.168101  0.603652  1.117381  0.305617
# 1      0.238398 -0.299152 -0.093351  0.514538  0.530172  0.787182
# 2      0.018122  0.044006  0.146898 -0.087546  0.110503 -0.006852
# 3      3.935517  1.284869  1.092597  4.786472  4.930754  4.767585
# 4      4.845847  1.284869  1.345327  4.887671  5.146680  4.873330
# ...         ...       ...       ...       ...       ...       ...
# 19995 -0.166267 -0.012215  0.103653  0.173453  0.381866  0.043137
# 19996  1.178751  0.649649  1.578495 -0.316586 -0.197651  0.302877
# 19997  0.882682 -0.804920 -0.391173  1.513210  1.568467  1.882627
# 19998  0.666557  0.485930  0.489306 -0.212908 -0.175844  0.546722
# 19999  0.607177  0.435387  0.497459  1.118045  1.506913  0.716247
#
# [20000 rows x 29 columns]

# %%
test_data.columns
# Out:
# Index(['temperature', 'dew_point_temperature', 'relative_humidity',
#        'atmospheric_pressure', 'precipitation', 'rain_days', 'country',
#        'fine_fuel_moisture_code_transformed', 'duff_moisture_code_transformed',
#        'drought_code_transformed', 'build_up_index_transformed',
#        'initial_spread_index_transformed', 'fire_weather_index_transformed',
#        'wind_speed_transformed', 'FFMC__TEMP', 'FFMC_RH', 'RH_TEMP', 'RD_FFMC',
#        'DC_RD', 'WS_TENP', 'IST_WS', 'ISI_FFMC', 'ISI_RH', 'DMC_TEMP',
#        'DMC_RD', 'RD_TEMP', 'DMC_DC', 'BUI_DC', 'BUI_DMC'],
#       dtype='object')

# %%
encoded_array = ohe.transform(test_data[['country']])  
encoded_df = pd.DataFrame(encoded_array, columns=ohe.get_feature_names_out(['country']))
new_data_encoded = pd.concat([test_data.reset_index(drop=True), encoded_df.reset_index(drop=True)], axis=1)

# %%
new_data_encoded = new_data_encoded.drop(['country'], axis =1)
new_data_encoded
# Out:
#        temperature  dew_point_temperature  relative_humidity  \
# 0         0.491152              -0.189652          -0.904141
# 1         0.272750              -0.247354          -0.796324
# 2        -0.245955               0.041156           0.183836
# 3        -1.829370              -1.314841           0.580800
# 4        -2.252524              -1.704330           0.624907
# ...            ...                    ...                ...
# 19995    -1.187814              -2.468882          -1.433427
# 19996     1.692363               1.209623          -0.668903
# 19997     0.654953              -0.175226          -0.972752
# 19998    -0.819261              -0.809948          -0.208228
# 19999    -0.832911              -0.406034           0.419074
#
#        atmospheric_pressure  precipitation  rain_days  \
# 0                  0.267098      -0.369007  -0.342258
# 1                  0.127932      -0.369007  -0.342258
# 2                  1.070668       0.297989  -0.597253
# 3                 -1.488187       0.747824  -0.597253
# 4                 -2.020907       3.245184  -0.597253
# ...                     ...            ...        ...
# 19995              0.756423      -0.369007  -0.087263
# 19996             -0.171349      -0.369007   0.932717
# 19997              0.531962      -0.353496  -0.597253
# 19998              1.504626       1.957725  -0.597253
# 19999             -0.353911       2.872907  -0.597253
#
#        fine_fuel_moisture_code_transformed  duff_moisture_code_transformed  \
# 0                                 0.788009                       -0.406332
# 1                                 0.624721                        0.874054
# 2                                -1.342731                       -0.073680
# 3                                -1.841822                       -2.151297
# 4                                -1.931812                       -2.151297
# ...                                    ...                             ...
# 19995                             0.815856                        0.139978
# 19996                             1.015918                        0.696512
# 19997                            -0.210901                        1.347702
# 19998                            -1.684157                       -0.813608
# 19999                            -1.796170                       -0.728982
#
#        drought_code_transformed  build_up_index_transformed  ...    DMC_RD  \
# 0                     -1.485611                   -0.752136  ...  0.139071
# 1                      0.588680                    0.900611  ... -0.299152
# 2                      1.188186                    0.093002  ...  0.044006
# 3                     -2.224924                   -2.216145  ...  1.284869
# 4                     -2.271965                   -2.265299  ...  1.284869
# ...                         ...                         ...  ...       ...
# 19995                  1.239147                    0.308168  ... -0.012215
# 19996                 -0.454530                    0.434848  ...  0.649649
# 19997                  1.122808                    1.396916  ... -0.804920
# 19998                  0.261683                   -0.671973  ...  0.485930
# 19999                 -1.533707                   -0.982530  ...  0.435387
#
#         RD_TEMP    DMC_DC    BUI_DC   BUI_DMC  country_Canada  country_France  \
# 0     -0.168101  0.603652  1.117381  0.305617               1               0
# 1     -0.093351  0.514538  0.530172  0.787182               1               0
# 2      0.146898 -0.087546  0.110503 -0.006852               1               0
# 3      1.092597  4.786472  4.930754  4.767585               1               0
# 4      1.345327  4.887671  5.146680  4.873330               1               0
# ...         ...       ...       ...       ...             ...             ...
# 19995  0.103653  0.173453  0.381866  0.043137               0               0
# 19996  1.578495 -0.316586 -0.197651  0.302877               0               0
# 19997 -0.391173  1.513210  1.568467  1.882627               1               0
# 19998  0.489306 -0.212908 -0.175844  0.546722               1               0
# 19999  0.497459  1.118045  1.506913  0.716247               1               0
#
#        country_Spain  country_United Kingdom  country_United States
# 0                  0                       0                      0
# 1                  0                       0                      0
# 2                  0                       0                      0
# 3                  0                       0                      0
# 4                  0                       0                      0
# ...              ...                     ...                    ...
# 19995              0                       0                      1
# 19996              0                       0                      1
# 19997              0                       0                      0
# 19998              0                       0                      0
# 19999              0                       0                      0
#
# [20000 rows x 33 columns]

# %%
# Prepare features and target from your new test data
X = new_data_encoded.drop('fire_weather_index_transformed', axis = 1)
y = new_data_encoded['fire_weather_index_transformed']

# %%
# Predict on the features
y_test_pred = LR_model.predict(X)

# Evaluate if target is available
if y is not None:
    from sklearn.metrics import r2_score, mean_squared_error
    print('Test R²:', r2_score(y, y_test_pred))
    print('Test MSE:', mean_squared_error(y, y_test_pred))
# Out:
# Test R²: 0.9756413940664943
# Test MSE: 0.026219634914734367

# %%
sns.scatterplot(x=y, y=y_test_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('test normalized Actual vs Predicted Scatterplot')
plt.savefig('test normalized+Act_vs_pred.png')
plt.show()

# %%
# number of features scaler was trained on
n_features = len(scaler.mean_)  

# index of target column inside scaler
col_index = list(scaler.feature_names_in_).index('fire_weather_index_transformed')

def inverse_single_column(scaler, values, col_index):
    """
    Inverse transform only one column of a StandardScaler.
    values: (n_samples,) array in scaled space for target column
    col_index: index of target column inside scaler.feature_names_in_
    """
    # create dummy matrix with correct number of features
    dummy = np.zeros((len(values), n_features))
    dummy[:, col_index] = values  # put values only in target column
    
    # inverse transform all features
    inv = scaler.inverse_transform(dummy)
    
    # extract only target column (now back in power-transform space)
    return inv[:, col_index]

# %%
# Step 1: inverse StandardScaler
y_train_pred_power = inverse_single_column(scaler, y_test_pred, col_index)
y_train_power = inverse_single_column(scaler, y, col_index)

# Step 2: inverse PowerTransformer
pt = power_transformers['fire_weather_index']
y_train_pred_orig = pt.inverse_transform(y_train_pred_power.reshape(-1, 1)).ravel()
y_train_orig = pt.inverse_transform(y_train_power.reshape(-1, 1)).ravel()

# Step 3: evaluate metrics
from sklearn.metrics import r2_score, mean_squared_error

train_r2_orig = r2_score(y_train_orig, y_train_pred_orig)
train_mse_orig = mean_squared_error(y_train_orig, y_train_pred_orig)

print('Original scale R²:', train_r2_orig)
print('Original scale MSE:', train_mse_orig)
# Out:
# Original scale R²: 0.32428309773768293
# Original scale MSE: 173.21906373313473

# %%
sns.scatterplot(x=y_train_orig, y=y_train_pred_orig)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Test Actual vs Test Predicted Scatterplot')
plt.savefig('Act_vs_pred_test.png')
plt.savefig("train_data.png")
plt.show()

# %%
import pickle
from sklearn.metrics import r2_score, mean_squared_error

# Load the pickled transformers in the same order they were applied

with open('path_to_scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)

with open('path_to_power_transformer.pkl', 'rb') as f:
    power_transformer = pickle.load(f)

# y_pred_transformed and y_test_transformed are 1D arrays/numpy arrays 
# from model predictions and true values on transformed + normalized scale

# Step 1: Inverse normalization (StandardScaler)
y_pred_norm_inverse = scaler.inverse_transform(y_pred_transformed.reshape(-1, 1))
y_test_norm_inverse = scaler.inverse_transform(y_test_transformed.reshape(-1, 1))

# Step 2: Inverse power transformation (e.g., PowerTransformer)
y_pred_original = power_transformer.inverse_transform(y_pred_norm_inverse).flatten()
y_test_original = power_transformer.inverse_transform(y_test_norm_inverse).flatten()

# Calculate metrics on original scale
r2_original = r2_score(y_test_original, y_pred_original)
mse_original = mean_squared_error(y_test_original, y_pred_original)

print(f'Original scale R²: {r2_original}')
print(f'Original scale MSE: {mse_original}')
