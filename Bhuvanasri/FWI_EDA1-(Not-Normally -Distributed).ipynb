# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\bhuva\train_data.csv')
data
# Out:
#                  report_date  temperature  dew_point_temperature  \
# 0        2013-10-31 12:00:00          5.7                   -6.0
# 1        2014-06-01 12:00:00         15.2                   10.1
# 2        2017-10-01 12:00:00          5.9                    4.2
# 3        2012-08-04 12:00:00         20.6                   15.4
# 4        2017-05-08 12:00:00         11.0                    6.0
# ...                      ...          ...                    ...
# 1183935  2018-08-24 12:00:00         11.5                    4.5
# 1183936  2010-06-02 12:00:00         17.9                    5.9
# 1183937  2016-08-18 12:00:00         18.4                    9.0
# 1183938  2016-10-21 12:00:00         11.0                   -1.0
# 1183939  2015-08-11 12:00:00         20.0                   14.0
#
#          relative_humidity  wind_speed  wind_direction  atmospheric_pressure  \
# 0                     42.0         5.0             135               1009.13
# 1                     71.0         5.6             170               1018.60
# 2                     88.0        27.9             321               1009.76
# 3                     71.0        19.8             197               1015.41
# 4                     71.5        13.0             260               1005.90
# ...                    ...         ...             ...                   ...
# 1183935               62.0        12.6             292               1015.70
# 1183936               45.5         7.4             220               1012.10
# 1183937               54.5        14.8             300               1017.10
# 1183938               43.6        29.6             260               1015.10
# 1183939               68.5        27.8             330               1016.10
#
#          visibility  precipitation  rain_days  ...  duff_moisture_code  \
# 0              39.3           0.00          1  ...                 6.5
# 1              30.1           0.00          5  ...                31.9
# 2              11.2           7.10          0  ...                14.5
# 3              21.1           0.00          1  ...                 6.1
# 4              16.1           0.25          0  ...                 4.4
# ...             ...            ...        ...  ...                 ...
# 1183935        17.9           0.20          0  ...                 1.9
# 1183936        24.0           0.00          2  ...                 5.8
# 1183937        19.8           0.00          1  ...                20.5
# 1183938        14.5           0.00          4  ...                 8.6
# 1183939        24.1           3.90          0  ...                31.0
#
#          drought_code  build_up_index  initial_spread_index  \
# 0               309.9            12.3                   0.7
# 1               172.7            43.7                   2.8
# 2               400.1            26.5                   0.2
# 3               242.0            11.4                   1.6
# 4                12.2             4.6                   1.4
# ...               ...             ...                   ...
# 1183935         138.9             3.7                   1.8
# 1183936          42.5             8.7                   3.1
# 1183937         130.0            29.4                   5.1
# 1183938         253.4            15.9                  11.8
# 1183939         285.4            48.7                   2.4
#
#          fire_weather_index  daily_severity_rating         country   latitude  \
# 0                       0.5                    0.0  United Kingdom  55.440834
# 1                       7.6                    1.0          Canada  48.460000
# 2                       0.2                    0.0          Canada  53.460000
# 3                       1.2                    0.0          Canada  53.350000
# 4                       0.6                    0.0   United States  43.645645
# ...                     ...                    ...             ...        ...
# 1183935                 0.7                    0.0          Canada  51.870000
# 1183936                 2.9                    0.2          Canada  49.910000
# 1183937                10.1                    1.6          Canada  51.770000
# 1183938                14.4                    3.0          Canada  49.520557
# 1183939                 7.1                    0.9          Canada  46.483334
#
#           longitude  elevation
# 0         -5.696944       12.8
# 1       -123.300000       60.1
# 2       -111.260000      656.0
# 3       -110.420000      664.0
# 4        -70.308620       23.1
# ...             ...        ...
# 1183935  -63.280000      588.9
# 1183936  -99.951940      409.4
# 1183937 -104.200000      560.1
# 1183938 -113.997220     1189.6
# 1183939  -84.509445      192.0
#
# [1183940 rows x 22 columns]

# %%
data.drop(['report_date'], axis =1 , inplace = True)

# %%
data.columns
# Out:
# Index(['temperature', 'dew_point_temperature', 'relative_humidity',
#        'wind_speed', 'wind_direction', 'atmospheric_pressure', 'visibility',
#        'precipitation', 'rain_days', 'snow_on_ground',
#        'fine_fuel_moisture_code', 'duff_moisture_code', 'drought_code',
#        'build_up_index', 'initial_spread_index', 'fire_weather_index',
#        'daily_severity_rating', 'country', 'latitude', 'longitude',
#        'elevation'],
#       dtype='object')

# %%
data
# Out:
#          temperature  dew_point_temperature  relative_humidity  wind_speed  \
# 0                5.7                   -6.0               42.0         5.0
# 1               15.2                   10.1               71.0         5.6
# 2                5.9                    4.2               88.0        27.9
# 3               20.6                   15.4               71.0        19.8
# 4               11.0                    6.0               71.5        13.0
# ...              ...                    ...                ...         ...
# 1183935         11.5                    4.5               62.0        12.6
# 1183936         17.9                    5.9               45.5         7.4
# 1183937         18.4                    9.0               54.5        14.8
# 1183938         11.0                   -1.0               43.6        29.6
# 1183939         20.0                   14.0               68.5        27.8
#
#          wind_direction  atmospheric_pressure  visibility  precipitation  \
# 0                   135               1009.13        39.3           0.00
# 1                   170               1018.60        30.1           0.00
# 2                   321               1009.76        11.2           7.10
# 3                   197               1015.41        21.1           0.00
# 4                   260               1005.90        16.1           0.25
# ...                 ...                   ...         ...            ...
# 1183935             292               1015.70        17.9           0.20
# 1183936             220               1012.10        24.0           0.00
# 1183937             300               1017.10        19.8           0.00
# 1183938             260               1015.10        14.5           0.00
# 1183939             330               1016.10        24.1           3.90
#
#          rain_days  snow_on_ground  ...  duff_moisture_code  drought_code  \
# 0                1             0.0  ...                 6.5         309.9
# 1                5             0.0  ...                31.9         172.7
# 2                0             0.0  ...                14.5         400.1
# 3                1             0.0  ...                 6.1         242.0
# 4                0             0.0  ...                 4.4          12.2
# ...            ...             ...  ...                 ...           ...
# 1183935          0             0.0  ...                 1.9         138.9
# 1183936          2             0.0  ...                 5.8          42.5
# 1183937          1             0.0  ...                20.5         130.0
# 1183938          4             0.0  ...                 8.6         253.4
# 1183939          0             0.0  ...                31.0         285.4
#
#          build_up_index  initial_spread_index  fire_weather_index  \
# 0                  12.3                   0.7                 0.5
# 1                  43.7                   2.8                 7.6
# 2                  26.5                   0.2                 0.2
# 3                  11.4                   1.6                 1.2
# 4                   4.6                   1.4                 0.6
# ...                 ...                   ...                 ...
# 1183935             3.7                   1.8                 0.7
# 1183936             8.7                   3.1                 2.9
# 1183937            29.4                   5.1                10.1
# 1183938            15.9                  11.8                14.4
# 1183939            48.7                   2.4                 7.1
#
#          daily_severity_rating         country   latitude   longitude  \
# 0                          0.0  United Kingdom  55.440834   -5.696944
# 1                          1.0          Canada  48.460000 -123.300000
# 2                          0.0          Canada  53.460000 -111.260000
# 3                          0.0          Canada  53.350000 -110.420000
# 4                          0.0   United States  43.645645  -70.308620
# ...                        ...             ...        ...         ...
# 1183935                    0.0          Canada  51.870000  -63.280000
# 1183936                    0.2          Canada  49.910000  -99.951940
# 1183937                    1.6          Canada  51.770000 -104.200000
# 1183938                    3.0          Canada  49.520557 -113.997220
# 1183939                    0.9          Canada  46.483334  -84.509445
#
#          elevation
# 0             12.8
# 1             60.1
# 2            656.0
# 3            664.0
# 4             23.1
# ...            ...
# 1183935      588.9
# 1183936      409.4
# 1183937      560.1
# 1183938     1189.6
# 1183939      192.0
#
# [1183940 rows x 21 columns]

# %%
data['country'].value_counts()
# Out:
# country
# Canada            807605
# United States     281247
# United Kingdom     53620
# France             32996
# Spain               8472
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#         temperature  dew_point_temperature  relative_humidity    wind_speed  \
# count  1.183940e+06           1.183940e+06       1.183940e+06  1.183940e+06
# mean   1.668434e+01           7.260763e+00       5.820264e+01  1.505470e+01
# std    7.875341e+00           7.342342e+00       2.121237e+01  9.489149e+00
# min   -7.270000e+01          -7.270000e+01       1.600000e+00  0.000000e+00
# 25%    1.120000e+01           2.500000e+00       4.230000e+01  8.000000e+00
# 50%    1.700000e+01           7.700000e+00       5.750000e+01  1.300000e+01
# 75%    2.220000e+01           1.230000e+01       7.420000e+01  2.040000e+01
# max    4.400000e+01           3.780000e+01       1.000000e+02  1.963000e+02
#
#        wind_direction  atmospheric_pressure    visibility  precipitation  \
# count    1.183940e+06          1.183940e+06  1.183940e+06   1.183940e+06
# mean     1.950146e+02          1.014547e+03  2.232443e+01   2.519198e+00
# std      1.027512e+02          7.407270e+00  1.009610e+01   7.159311e+00
# min      0.000000e+00          9.500000e+02  0.000000e+00   0.000000e+00
# 25%      1.200000e+02          1.010100e+03  1.610000e+01   0.000000e+00
# 50%      2.100000e+02          1.014800e+03  1.990000e+01   0.000000e+00
# 75%      2.800000e+02          1.019300e+03  2.500000e+01   1.500000e+00
# max      3.600000e+02          1.057000e+03  9.650000e+01   1.185700e+03
#
#           rain_days  snow_on_ground  fine_fuel_moisture_code  \
# count  1.183940e+06    1.183940e+06             1.183940e+06
# mean   2.505681e+00    1.742909e-04             7.359950e+01
# std    4.619977e+00    1.613532e-01             2.070757e+01
# min    0.000000e+00    0.000000e+00             0.000000e+00
# 25%    0.000000e+00    0.000000e+00             6.460000e+01
# 50%    1.000000e+00    0.000000e+00             8.240000e+01
# 75%    3.000000e+00    0.000000e+00             8.800000e+01
# max    1.570000e+02    1.750000e+02             1.000000e+02
#
#        duff_moisture_code  drought_code  build_up_index  initial_spread_index  \
# count        1.183940e+06  1.183940e+06    1.183940e+06          1.183940e+06
# mean         2.791664e+01  2.480187e+02    3.981740e+01          5.400023e+00
# std          4.284811e+01  2.251169e+02    5.231052e+01          9.980017e+00
# min          0.000000e+00 -9.900000e+01    0.000000e+00          0.000000e+00
# 25%          6.400000e+00  8.060000e+01    1.000000e+01          1.000000e+00
# 50%          1.560000e+01  1.983000e+02    2.410000e+01          3.100000e+00
# 75%          3.340000e+01  3.491000e+02    4.990000e+01          6.800000e+00
# max          1.206600e+03  2.143800e+03    1.190800e+03          3.919700e+03
#
#        fire_weather_index  daily_severity_rating      latitude     longitude  \
# count        1.183940e+06           1.183940e+06  1.183940e+06  1.183940e+06
# mean         1.112798e+01           4.285194e+00  4.809259e+01 -9.029378e+01
# std          1.584219e+01           1.330087e+01  7.474082e+00  3.380679e+01
# min          0.000000e+00           0.000000e+00  2.590614e+01 -1.766425e+02
# 25%          6.000000e-01           0.000000e+00  4.427222e+01 -1.135900e+02
# 50%          5.500000e+00           6.000000e-01  4.913000e+01 -9.786000e+01
# 75%          1.530000e+01           3.400000e+00  5.259000e+01 -7.375000e+01
# max          5.111000e+02           1.692900e+03  8.250000e+01  9.541389e+00
#
#           elevation
# count  1.183940e+06
# mean   4.015977e+02
# std    4.224224e+02
# min    0.000000e+00
# 25%    5.800000e+01
# 50%    2.510000e+02
# 75%    6.570000e+02
# max    2.575000e+03

# %%
#Univariate Analysis

for col in data.select_dtypes(include=['float64','int64']).columns:
    plt.figure(figsize=(6,4))
    sns.histplot(data[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
#Univariate Analysis

for col in data.select_dtypes(include=['float64','int64']).columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(y = data[col])
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
target = 'fire_weather_index'

numeric_data = data.select_dtypes(include=['number'])
correlations = numeric_data.corr()[target].sort_values(ascending=False)
print("Correlations with target variable:\n", correlations)

# Scatter plots for each feature vs. target variable
features = [col for col in data.columns if col != target and data[col].dtype != 'object']

for feature in features:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=data[feature], y=data[target])
    plt.title(f'{feature} vs {target}')
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.tight_layout()
    plt.show()
# Out:
# Correlations with target variable:
#  fire_weather_index         1.000000
# daily_severity_rating      0.866622
# initial_spread_index       0.786061
# build_up_index             0.702458
# duff_moisture_code         0.663878
# drought_code               0.565405
# fine_fuel_moisture_code    0.530670
# rain_days                  0.441369
# temperature                0.430584
# elevation                  0.408807
# wind_speed                 0.288456
# wind_direction             0.048566
# visibility                 0.012300
# snow_on_ground            -0.000305
# atmospheric_pressure      -0.070854
# dew_point_temperature     -0.171916
# latitude                  -0.185869
# longitude                 -0.199923
# precipitation             -0.226314
# relative_humidity         -0.617657
# Name: fire_weather_index, dtype: float64

# %%
df_sample = data.sample(n=4000, random_state=42)  
print(df_sample.shape)
# Out:
# (4000, 22)

# %%
#Univariate Analysis

for col in df_sample.select_dtypes(include=['float64','int64']).columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df_sample[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
#Univariate Analysis

for col in df_sample.select_dtypes(include=['float64','int64']).columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(y = df_sample[col])
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
target = 'fire_weather_index'

numeric_data = df_sample.select_dtypes(include=['number'])
correlations = numeric_data.corr()[target].sort_values(ascending=False)
print("Correlations with target variable:\n", correlations)

# Scatter plots for each feature vs. target variable
features = [col for col in df_sample.columns if col != target and df_sample[col].dtype != 'object']

for feature in features:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=df_sample[feature], y=df_sample[target])
    plt.title(f'{feature} vs {target}')
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.tight_layout()
    plt.show()

# %%
target = 'fire_weather_index'

numeric_data = df_sample.select_dtypes(include=['number'])
correlations = numeric_data.corr()[target].sort_values(ascending=False)
print("Correlations with target variable:\n", correlations)

# Scatter plots for each feature vs. target variable
features = [col for col in df_sample.columns if col != target and df_sample[col].dtype != 'object']

for feature in features:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=df_sample[feature], y=df_sample[target],alpha= 0.2)
    plt.title(f'{feature} vs {target}')
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.tight_layout()
    plt.show()

# %%
target = 'fire_weather_index'

numeric_data = df_sample.select_dtypes(include=['number'])
correlations = numeric_data.corr()[target].sort_values(ascending=False)
print("Correlations with target variable:\n", correlations)

# Scatter plots for each feature vs. target variable
features = [col for col in df_sample.columns if col != target and df_sample[col].dtype != 'object']

for feature in features:
    plt.figure(figsize=(6, 4))
    sns.regplot(x=df_sample[feature], y=df_sample[target], scatter_kws={'alpha':0.2})
    plt.title(f'{feature} vs {target}')
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.tight_layout()
    plt.show()

# %%
# Select only numeric columns
num_df = df_sample.select_dtypes(include=['number'])

# Compute Pearson and Spearman correlation matrices
pearson_corr = num_df.corr(method='pearson')
spearman_corr = num_df.corr(method='spearman')

# %%
pearson_corr
# Out:
#                          temperature  dew_point_temperature  \
# temperature                 1.000000               0.622382
# dew_point_temperature       0.622382               1.000000
# relative_humidity          -0.446314               0.383716
# wind_speed                 -0.114339              -0.117337
# wind_direction             -0.015875              -0.063242
# atmospheric_pressure       -0.084756              -0.167038
# visibility                  0.005118              -0.141113
# precipitation              -0.104485               0.109579
# rain_days                   0.169801              -0.072770
# snow_on_ground                   NaN                    NaN
# fine_fuel_moisture_code     0.462530              -0.078461
# duff_moisture_code          0.345711              -0.090880
# drought_code                0.219248              -0.114822
# build_up_index              0.358029              -0.087653
# initial_spread_index        0.339336              -0.223731
# fire_weather_index          0.426807              -0.190785
# daily_severity_rating       0.306291              -0.195774
# latitude                   -0.299218              -0.178045
# longitude                  -0.023018               0.115487
# elevation                   0.067486              -0.311338
#
#                          relative_humidity  wind_speed  wind_direction  \
# temperature                      -0.446314   -0.114339       -0.015875
# dew_point_temperature             0.383716   -0.117337       -0.063242
# relative_humidity                 1.000000    0.009918       -0.074995
# wind_speed                        0.009918    1.000000        0.153508
# wind_direction                   -0.074995    0.153508        1.000000
# atmospheric_pressure             -0.142121   -0.175591       -0.048107
# visibility                       -0.233426   -0.086332        0.037332
# precipitation                     0.281333    0.035709       -0.008202
# rain_days                        -0.259629    0.001265       -0.020419
# snow_on_ground                         NaN         NaN             NaN
# fine_fuel_moisture_code          -0.694466    0.005919        0.037088
# duff_moisture_code               -0.424011   -0.046357       -0.023767
# drought_code                     -0.339246   -0.036209       -0.003873
# build_up_index                   -0.441942   -0.046961       -0.016592
# initial_spread_index             -0.577616    0.421588        0.055448
# fire_weather_index               -0.631051    0.271161        0.035927
# daily_severity_rating            -0.465029    0.264218        0.031716
# latitude                          0.117623   -0.080055       -0.014556
# longitude                         0.147288   -0.027769       -0.092421
# elevation                        -0.391366    0.031335        0.070318
#
#                          atmospheric_pressure  visibility  precipitation  \
# temperature                         -0.084756    0.005118      -0.104485
# dew_point_temperature               -0.167038   -0.141113       0.109579
# relative_humidity                   -0.142121   -0.233426       0.281333
# wind_speed                          -0.175591   -0.086332       0.035709
# wind_direction                      -0.048107    0.037332      -0.008202
# atmospheric_pressure                 1.000000    0.053922      -0.172524
# visibility                           0.053922    1.000000      -0.117934
# precipitation                       -0.172524   -0.117934       1.000000
# rain_days                            0.064690   -0.015198      -0.190839
# snow_on_ground                            NaN         NaN            NaN
# fine_fuel_moisture_code              0.172620    0.184889      -0.573981
# duff_moisture_code                  -0.001695   -0.007067      -0.161980
# drought_code                         0.021690    0.055195      -0.166459
# build_up_index                       0.001356    0.008704      -0.177313
# initial_spread_index                -0.051172    0.024094      -0.222733
# fire_weather_index                  -0.038808    0.022741      -0.233859
# daily_severity_rating               -0.063456   -0.028152      -0.128706
# latitude                            -0.145448    0.286126      -0.008385
# longitude                            0.010428   -0.018065       0.070651
# elevation                            0.002901    0.081293      -0.058924
#
#                          rain_days  snow_on_ground  fine_fuel_moisture_code  \
# temperature               0.169801             NaN                 0.462530
# dew_point_temperature    -0.072770             NaN                -0.078461
# relative_humidity        -0.259629             NaN                -0.694466
# wind_speed                0.001265             NaN                 0.005919
# wind_direction           -0.020419             NaN                 0.037088
# atmospheric_pressure      0.064690             NaN                 0.172620
# visibility               -0.015198             NaN                 0.184889
# precipitation            -0.190839             NaN                -0.573981
# rain_days                 1.000000             NaN                 0.363884
# snow_on_ground                 NaN             NaN                      NaN
# fine_fuel_moisture_code   0.363884             NaN                 1.000000
# duff_moisture_code        0.392752             NaN                 0.389198
# drought_code              0.284396             NaN                 0.332699
# build_up_index            0.398518             NaN                 0.417571
# initial_spread_index      0.343779             NaN                 0.502995
# fire_weather_index        0.438266             NaN                 0.548551
# daily_severity_rating     0.335668             NaN                 0.333987
# latitude                 -0.166010             NaN                -0.113290
# longitude                -0.125207             NaN                -0.138821
# elevation                 0.102613             NaN                 0.225371
#
#                          duff_moisture_code  drought_code  build_up_index  \
# temperature                        0.345711      0.219248        0.358029
# dew_point_temperature             -0.090880     -0.114822       -0.087653
# relative_humidity                 -0.424011     -0.339246       -0.441942
# wind_speed                        -0.046357     -0.036209       -0.046961
# wind_direction                    -0.023767     -0.003873       -0.016592
# atmospheric_pressure              -0.001695      0.021690        0.001356
# visibility                        -0.007067      0.055195        0.008704
# precipitation                     -0.161980     -0.166459       -0.177313
# rain_days                          0.392752      0.284396        0.398518
# snow_on_ground                          NaN           NaN             NaN
# fine_fuel_moisture_code            0.389198      0.332699        0.417571
# duff_moisture_code                 1.000000      0.700511        0.979820
# drought_code                       0.700511      1.000000        0.800804
# build_up_index                     0.979820      0.800804        1.000000
# initial_spread_index               0.430194      0.345357        0.447652
# fire_weather_index                 0.680386      0.572861        0.714982
# daily_severity_rating              0.577814      0.482476        0.602784
# latitude                          -0.157053     -0.037032       -0.150142
# longitude                         -0.208503     -0.293986       -0.237233
# elevation                          0.356142      0.438165        0.396182
#
#                          initial_spread_index  fire_weather_index  \
# temperature                          0.339336            0.426807
# dew_point_temperature               -0.223731           -0.190785
# relative_humidity                   -0.577616           -0.631051
# wind_speed                           0.421588            0.271161
# wind_direction                       0.055448            0.035927
# atmospheric_pressure                -0.051172           -0.038808
# visibility                           0.024094            0.022741
# precipitation                       -0.222733           -0.233859
# rain_days                            0.343779            0.438266
# snow_on_ground                            NaN                 NaN
# fine_fuel_moisture_code              0.502995            0.548551
# duff_moisture_code                   0.430194            0.680386
# drought_code                         0.345357            0.572861
# build_up_index                       0.447652            0.714982
# initial_spread_index                 1.000000            0.905683
# fire_weather_index                   0.905683            1.000000
# daily_severity_rating                0.875847            0.908978
# latitude                            -0.186244           -0.204727
# longitude                           -0.131392           -0.194824
# elevation                            0.340940            0.421691
#
#                          daily_severity_rating  latitude  longitude  elevation
# temperature                           0.306291 -0.299218  -0.023018   0.067486
# dew_point_temperature                -0.195774 -0.178045   0.115487  -0.311338
# relative_humidity                    -0.465029  0.117623   0.147288  -0.391366
# wind_speed                            0.264218 -0.080055  -0.027769   0.031335
# wind_direction                        0.031716 -0.014556  -0.092421   0.070318
# atmospheric_pressure                 -0.063456 -0.145448   0.010428   0.002901
# visibility                           -0.028152  0.286126  -0.018065   0.081293
# precipitation                        -0.128706 -0.008385   0.070651  -0.058924
# rain_days                             0.335668 -0.166010  -0.125207   0.102613
# snow_on_ground                             NaN       NaN        NaN        NaN
# fine_fuel_moisture_code               0.333987 -0.113290  -0.138821   0.225371
# duff_moisture_code                    0.577814 -0.157053  -0.208503   0.356142
# drought_code                          0.482476 -0.037032  -0.293986   0.438165
# build_up_index                        0.602784 -0.150142  -0.237233   0.396182
# initial_spread_index                  0.875847 -0.186244  -0.131392   0.340940
# fire_weather_index                    0.908978 -0.204727  -0.194824   0.421691
# daily_severity_rating                 1.000000 -0.193827  -0.141928   0.368067
# latitude                             -0.193827  1.000000  -0.159210  -0.048158
# longitude                            -0.141928 -0.159210   1.000000  -0.323802
# elevation                             0.368067 -0.048158  -0.323802   1.000000

# %%
plt.figure(figsize=(14,8))
sns.heatmap(pearson_corr, annot=True, cmap="coolwarm")
plt.title("Pearson Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.heatmap(spearman_corr, annot=True, cmap="coolwarm")
plt.title("spearman Correlation Heatmap")
plt.show()

# %%
#statistical analysis

# %%
#Histogram / KDE plot

#Q–Q plot

#Shapiro-Wilk test (p > 0.05 → data looks normal)

# %%
#Normality of numerical data

#Histogram / KDE plot

#Q–Q plot

#Shapiro-Wilk test (p > 0.05 → data looks normal)

# %%
import scipy.stats as stats

col = "fine_fuel_moisture_code" 
data_col = data[col]

# 1. Histogram + KDE
plt.figure(figsize=(8,5))
sns.histplot(data_col, kde=True, bins=30)
plt.title(f"Histogram + KDE for {col}")
plt.show()

# 2. Q-Q plot
plt.figure(figsize=(6,6))
stats.probplot(data_col, dist="norm", plot=plt)
plt.title(f"Q-Q plot for {col}")
plt.show()

# 3. Shapiro-Wilk test
shapiro_stat, shapiro_p = stats.shapiro(data_col)
print(f"Shapiro-Wilk Test for {col}: Statistic={shapiro_stat:.3f}, p-value={shapiro_p:.3f}")

if shapiro_p > 0.05:
    print("Data looks normally distributed (fail to reject H0).")
else:
    print("Data is not normally distributed (reject H0).")
# Out:
# Shapiro-Wilk Test for fine_fuel_moisture_code: Statistic=0.828, p-value=0.000
# Data is not normally distributed (reject H0).
# C:\Users\bhuva\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\stats\_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 1183940.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
data.plot(kind ='scatter',y='latitude', x='longitude',grid = True)
plt.show()

# %%
data.plot(kind ='scatter',y='latitude', x='longitude',grid = True, s =data['temperature'], 
          label = 'temperature', c = 'fire_weather_index', cmap = 'jet', colorbar = True,
         legend = True, figsize= (10,7))
plt.show()
# Out:
# C:\Users\bhuva\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\collections.py:999: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
