# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Infosys_Spring_Project\standardized_data.csv')
data
# Out:
#          temperature  dew_point_temperature  relative_humidity  \
# 0          -1.542278              -1.978163          -0.796962
# 1          -0.245406               0.344369           0.625454
# 2          -1.514975              -0.506746           1.459284
# 3           0.491763               1.108929           0.625454
# 4          -0.818760              -0.247084           0.649978
# ...              ...                    ...                ...
# 1085215    -0.750504              -0.463469           0.184015
# 1085216     0.123178              -0.261509          -0.625291
# 1085217     0.191435               0.185686          -0.183852
# 1085218    -0.818760              -1.256880          -0.718484
# 1085219     0.409855               0.906970           0.502832
#
#          atmospheric_pressure  precipitation  rain_days         country  \
# 0                   -0.840463      -0.368696  -0.343121  United Kingdom
# 1                    0.576804      -0.368696   0.678118          Canada
# 2                   -0.746179       0.730860  -0.598430          Canada
# 3                    0.099393      -0.368696  -0.343121          Canada
# 4                   -1.323861      -0.329979  -0.598430   United States
# ...                       ...            ...        ...             ...
# 1085215              0.142794      -0.337722  -0.598430          Canada
# 1085216             -0.395977      -0.368696  -0.087811          Canada
# 1085217              0.352316      -0.368696  -0.343121          Canada
# 1085218              0.052999      -0.368696   0.422808          Canada
# 1085219              0.202657       0.235285  -0.598430          Canada
#
#          fine_fuel_moisture_code_transformed  duff_moisture_code_transformed  \
# 0                                  -0.805687                       -0.670963
# 1                                   0.537518                        0.642961
# 2                                  -1.704931                       -0.069545
# 3                                  -0.668007                       -0.713890
# 4                                  -0.310054                       -0.924793
# ...                                      ...                             ...
# 1085215                            -0.030169                       -1.397569
# 1085216                             0.528867                       -0.747520
# 1085217                             0.625089                        0.227201
# 1085218                             0.678563                       -0.473890
# 1085219                            -0.645071                        0.614727
#
#          drought_code_transformed  build_up_index_transformed  \
# 0                        0.583845                   -0.541734
# 1                       -0.068498                    0.557491
# 2                        0.920752                    0.080045
# 3                        0.289089                   -0.596800
# 4                       -1.680780                   -1.176885
# ...                           ...                         ...
# 1085215                 -0.274843                   -1.296851
# 1085216                 -1.128693                   -0.784089
# 1085217                 -0.334077                    0.174121
# 1085218                  0.341752                   -0.347429
# 1085219                  0.482411                    0.669345
#
#          initial_spread_index_transformed  fire_weather_index_transformed  \
# 0                               -0.997918                       -0.824827
# 1                               -0.044330                        0.325514
# 2                               -1.429882                       -1.070028
# 3                               -0.486723                       -0.532715
# 4                               -0.581727                       -0.769029
# ...                                   ...                             ...
# 1085215                         -0.399293                       -0.719867
# 1085216                          0.042679                       -0.168828
# 1085217                          0.489266                        0.493980
# 1085218                          1.286050                        0.720238
# 1085219                         -0.172630                        0.286824
#
#          wind_speed_transformed
# 0                     -1.401004
# 1                     -1.263390
# 2                      1.382750
# 3                      0.690174
# 4                     -0.055960
# ...                         ...
# 1085215               -0.107230
# 1085216               -0.901477
# 1085217                0.162710
# 1085218                1.510608
# 1085219                1.375071
#
# [1085220 rows x 14 columns]

# %%
data.columns
# Out:
# Index(['temperature', 'dew_point_temperature', 'relative_humidity',
#        'atmospheric_pressure', 'precipitation', 'rain_days', 'country',
#        'fine_fuel_moisture_code_transformed', 'duff_moisture_code_transformed',
#        'drought_code_transformed', 'build_up_index_transformed',
#        'initial_spread_index_transformed', 'fire_weather_index_transformed',
#        'wind_speed_transformed'],
#       dtype='object')

# %%
data['FFMC__TEMP'] = data['temperature'] * data['fine_fuel_moisture_code_transformed']
data['FFMC_RH'] = data['relative_humidity'] * data['fine_fuel_moisture_code_transformed']
data['RH_TEMP'] = data['temperature'] * data['relative_humidity']
data['RD_FFMC'] =  data['fine_fuel_moisture_code_transformed'] * data['rain_days']
data['DC_RD'] =  data['drought_code_transformed'] * data['rain_days']
data['WS_TENP'] =  data['wind_speed_transformed'] * data['fine_fuel_moisture_code_transformed']
data['IST_WS'] =  data['wind_speed_transformed'] * data['initial_spread_index_transformed']
data['ISI_FFMC'] =  data['initial_spread_index_transformed'] * data['fine_fuel_moisture_code_transformed']
data['ISI_RH'] =  data['initial_spread_index_transformed'] * data['relative_humidity']
data['DMC_TEMP'] =  data['duff_moisture_code_transformed'] * data['temperature']
data['DMC_RD'] =  data['duff_moisture_code_transformed'] * data['rain_days']
data['RD_TEMP'] =  data['rain_days'] * data['temperature']
data['DMC_DC'] =  data['drought_code_transformed'] * data['duff_moisture_code_transformed']
data['BUI_DC'] =  data['drought_code_transformed'] * data['build_up_index_transformed']
data['BUI_DMC'] =  data['duff_moisture_code_transformed'] * data['build_up_index_transformed']

# %%
data
# Out:
#          temperature  dew_point_temperature  relative_humidity  \
# 0          -1.542278              -1.978163          -0.796962
# 1          -0.245406               0.344369           0.625454
# 2          -1.514975              -0.506746           1.459284
# 3           0.491763               1.108929           0.625454
# 4          -0.818760              -0.247084           0.649978
# ...              ...                    ...                ...
# 1085215    -0.750504              -0.463469           0.184015
# 1085216     0.123178              -0.261509          -0.625291
# 1085217     0.191435               0.185686          -0.183852
# 1085218    -0.818760              -1.256880          -0.718484
# 1085219     0.409855               0.906970           0.502832
#
#          atmospheric_pressure  precipitation  rain_days         country  \
# 0                   -0.840463      -0.368696  -0.343121  United Kingdom
# 1                    0.576804      -0.368696   0.678118          Canada
# 2                   -0.746179       0.730860  -0.598430          Canada
# 3                    0.099393      -0.368696  -0.343121          Canada
# 4                   -1.323861      -0.329979  -0.598430   United States
# ...                       ...            ...        ...             ...
# 1085215              0.142794      -0.337722  -0.598430          Canada
# 1085216             -0.395977      -0.368696  -0.087811          Canada
# 1085217              0.352316      -0.368696  -0.343121          Canada
# 1085218              0.052999      -0.368696   0.422808          Canada
# 1085219              0.202657       0.235285  -0.598430          Canada
#
#          fine_fuel_moisture_code_transformed  duff_moisture_code_transformed  \
# 0                                  -0.805687                       -0.670963
# 1                                   0.537518                        0.642961
# 2                                  -1.704931                       -0.069545
# 3                                  -0.668007                       -0.713890
# 4                                  -0.310054                       -0.924793
# ...                                      ...                             ...
# 1085215                            -0.030169                       -1.397569
# 1085216                             0.528867                       -0.747520
# 1085217                             0.625089                        0.227201
# 1085218                             0.678563                       -0.473890
# 1085219                            -0.645071                        0.614727
#
#          drought_code_transformed  ...   WS_TENP    IST_WS  ISI_FFMC  \
# 0                        0.583845  ...  1.128771  1.398088  0.804010
# 1                       -0.068498  ... -0.679095  0.056006 -0.023828
# 2                        0.920752  ... -2.357493 -1.977169  2.437849
# 3                        0.289089  ... -0.461041 -0.335923  0.325134
# 4                       -1.680780  ...  0.017351  0.032553  0.180367
# ...                           ...  ...       ...       ...       ...
# 1085215                 -0.274843  ...  0.003235  0.042816  0.012046
# 1085216                 -1.128693  ... -0.476761 -0.038474  0.022572
# 1085217                 -0.334077  ...  0.101708  0.079608  0.305835
# 1085218                  0.341752  ...  1.025042  1.942716  0.872665
# 1085219                  0.482411  ... -0.887018 -0.237379  0.111359
#
#            ISI_RH  DMC_TEMP    DMC_RD   RD_TEMP    DMC_DC    BUI_DC   BUI_DMC
# 0        0.795303  1.034812  0.230221  0.529187 -0.391738 -0.316288  0.363483
# 1       -0.027726 -0.157787  0.436003 -0.166414 -0.044041 -0.038187  0.358445
# 2       -2.086604  0.105359  0.041618  0.906607 -0.064034  0.073701 -0.005567
# 3       -0.304423 -0.351065  0.244950 -0.168734 -0.206378 -0.172529  0.426050
# 4       -0.378110  0.757184  0.553424  0.489971  1.554373  1.978084  1.088375
# ...           ...       ...       ...       ...       ...       ...       ...
# 1085215 -0.073476  1.048881  0.836348  0.449124  0.384112  0.356431  1.812439
# 1085216 -0.026687 -0.092078  0.065640 -0.010816  0.843720  0.884995  0.586122
# 1085217 -0.089952  0.043494 -0.077957 -0.065685 -0.075902 -0.058170  0.039560
# 1085218 -0.924006  0.388002 -0.200364 -0.346178 -0.161953 -0.118735  0.164643
# 1085219 -0.086804  0.251949 -0.367871 -0.245270  0.296551  0.322899  0.411464
#
# [1085220 rows x 29 columns]

# %%
df_encoded = pd.get_dummies(data, columns=['country'], dtype=int)
df_encoded
# Out:
#          temperature  dew_point_temperature  relative_humidity  \
# 0          -1.542278              -1.978163          -0.796962
# 1          -0.245406               0.344369           0.625454
# 2          -1.514975              -0.506746           1.459284
# 3           0.491763               1.108929           0.625454
# 4          -0.818760              -0.247084           0.649978
# ...              ...                    ...                ...
# 1085215    -0.750504              -0.463469           0.184015
# 1085216     0.123178              -0.261509          -0.625291
# 1085217     0.191435               0.185686          -0.183852
# 1085218    -0.818760              -1.256880          -0.718484
# 1085219     0.409855               0.906970           0.502832
#
#          atmospheric_pressure  precipitation  rain_days  \
# 0                   -0.840463      -0.368696  -0.343121
# 1                    0.576804      -0.368696   0.678118
# 2                   -0.746179       0.730860  -0.598430
# 3                    0.099393      -0.368696  -0.343121
# 4                   -1.323861      -0.329979  -0.598430
# ...                       ...            ...        ...
# 1085215              0.142794      -0.337722  -0.598430
# 1085216             -0.395977      -0.368696  -0.087811
# 1085217              0.352316      -0.368696  -0.343121
# 1085218              0.052999      -0.368696   0.422808
# 1085219              0.202657       0.235285  -0.598430
#
#          fine_fuel_moisture_code_transformed  duff_moisture_code_transformed  \
# 0                                  -0.805687                       -0.670963
# 1                                   0.537518                        0.642961
# 2                                  -1.704931                       -0.069545
# 3                                  -0.668007                       -0.713890
# 4                                  -0.310054                       -0.924793
# ...                                      ...                             ...
# 1085215                            -0.030169                       -1.397569
# 1085216                             0.528867                       -0.747520
# 1085217                             0.625089                        0.227201
# 1085218                             0.678563                       -0.473890
# 1085219                            -0.645071                        0.614727
#
#          drought_code_transformed  build_up_index_transformed  ...    DMC_RD  \
# 0                        0.583845                   -0.541734  ...  0.230221
# 1                       -0.068498                    0.557491  ...  0.436003
# 2                        0.920752                    0.080045  ...  0.041618
# 3                        0.289089                   -0.596800  ...  0.244950
# 4                       -1.680780                   -1.176885  ...  0.553424
# ...                           ...                         ...  ...       ...
# 1085215                 -0.274843                   -1.296851  ...  0.836348
# 1085216                 -1.128693                   -0.784089  ...  0.065640
# 1085217                 -0.334077                    0.174121  ... -0.077957
# 1085218                  0.341752                   -0.347429  ... -0.200364
# 1085219                  0.482411                    0.669345  ... -0.367871
#
#           RD_TEMP    DMC_DC    BUI_DC   BUI_DMC  country_Canada  \
# 0        0.529187 -0.391738 -0.316288  0.363483               0
# 1       -0.166414 -0.044041 -0.038187  0.358445               1
# 2        0.906607 -0.064034  0.073701 -0.005567               1
# 3       -0.168734 -0.206378 -0.172529  0.426050               1
# 4        0.489971  1.554373  1.978084  1.088375               0
# ...           ...       ...       ...       ...             ...
# 1085215  0.449124  0.384112  0.356431  1.812439               1
# 1085216 -0.010816  0.843720  0.884995  0.586122               1
# 1085217 -0.065685 -0.075902 -0.058170  0.039560               1
# 1085218 -0.346178 -0.161953 -0.118735  0.164643               1
# 1085219 -0.245270  0.296551  0.322899  0.411464               1
#
#          country_France  country_Spain  country_United Kingdom  \
# 0                     0              0                       1
# 1                     0              0                       0
# 2                     0              0                       0
# 3                     0              0                       0
# 4                     0              0                       0
# ...                 ...            ...                     ...
# 1085215               0              0                       0
# 1085216               0              0                       0
# 1085217               0              0                       0
# 1085218               0              0                       0
# 1085219               0              0                       0
#
#          country_United States
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            1
# ...                        ...
# 1085215                      0
# 1085216                      0
# 1085217                      0
# 1085218                      0
# 1085219                      0
#
# [1085220 rows x 33 columns]

# %%
df_encoded.columns
# Out:
# Index(['temperature', 'dew_point_temperature', 'relative_humidity',
#        'atmospheric_pressure', 'precipitation', 'rain_days',
#        'fine_fuel_moisture_code_transformed', 'duff_moisture_code_transformed',
#        'drought_code_transformed', 'build_up_index_transformed',
#        'initial_spread_index_transformed', 'fire_weather_index_transformed',
#        'wind_speed_transformed', 'FFMC__TEMP', 'FFMC_RH', 'RH_TEMP', 'RD_FFMC',
#        'DC_RD', 'WS_TENP', 'IST_WS', 'ISI_FFMC', 'ISI_RH', 'DMC_TEMP',
#        'DMC_RD', 'RD_TEMP', 'DMC_DC', 'BUI_DC', 'BUI_DMC', 'country_Canada',
#        'country_France', 'country_Spain', 'country_United Kingdom',
#        'country_United States'],
#       dtype='object')

# %%
data = df_encoded
data.columns
# Out:
# Index(['temperature', 'dew_point_temperature', 'relative_humidity',
#        'atmospheric_pressure', 'precipitation', 'rain_days',
#        'fine_fuel_moisture_code_transformed', 'duff_moisture_code_transformed',
#        'drought_code_transformed', 'build_up_index_transformed',
#        'initial_spread_index_transformed', 'fire_weather_index_transformed',
#        'wind_speed_transformed', 'FFMC__TEMP', 'FFMC_RH', 'RH_TEMP', 'RD_FFMC',
#        'DC_RD', 'WS_TENP', 'IST_WS', 'ISI_FFMC', 'ISI_RH', 'DMC_TEMP',
#        'DMC_RD', 'RD_TEMP', 'DMC_DC', 'BUI_DC', 'BUI_DMC', 'country_Canada',
#        'country_France', 'country_Spain', 'country_United Kingdom',
#        'country_United States'],
#       dtype='object')

# %%
data.shape
# Out:
# (1085220, 33)

# %%
data.to_csv(r'C:\Infosys_Spring_Project\Interaction_data.csv', index=False)
